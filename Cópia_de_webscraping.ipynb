# %% [markdown]
# <a href="https://colab.research.google.com/github/alexandreWachRch/aulas_datascience/blob/master/C%C3%B3pia_de_webscraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
# !pip install beautifulsoup4

# %%
url = 'https://www.gov.br/receitafederal/pt-br/assuntos/agenda-tributaria/2026/fevereiro/diario'

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd

# %%
html = urlopen(url)

# %%
tabela = bs.find("table")

linhas = tabela.find_all("tr")

for linha in linhas:
    colunas = [c.get_text(strip=True) for c in linha.find_all(["td", "th"])]
    print(colunas)
# Out:
# ['Código de Receita', 'Grupo de Tributo', 'Descrição', 'Período de Apuração']
# ['Documento Arrecadação', 'Categoria da Declaração / Origem Escrituração', 'Fundamentação Legal']
# ['2063', 'IRRF', 'Rendimentos do Trabalho - Tributação exclusiva sobre remuneração indireta', 'FG ocorrido no mesmo dia(DD/MM/AAAA)']
# ['DARF', 'DCTFWeb Geral Mensal / Reinf RET', 'Lei nº 7.713/88 Art. 7º']
# ['0422', 'IRRF', 'Royalties e Assistência Técnica - Residentes no Exterior', 'FG ocorrido no mesmo dia(DD/MM/AAAA)']
# ['DARF', 'DCTFWeb Geral Mensal / Reinf RET', 'MP nº 2.159-70/01 Art. 3º']
# ['0473', 'IRRF', 'Renda e proventos de qualquer natureza - Residentes no Exterior', 'FG ocorrido no mesmo dia(DD/MM/AAAA)']
# ['DARF', 'DCTFWeb Geral Mensal / eSocial', 'Decreto-Lei nº 5.844/43 Art. 97']
# ['0481', 'IRRF', 'Juros e Comissões em Geral - Residentes no Exterior', 'FG ocorrido no mesmo dia(DD/MM/AAAA)']
# ['DARF', 'DCTFWeb Geral Mensal / Reinf RET', 'Decreto-Lei nº 401/68 Art. 11']
# ...
